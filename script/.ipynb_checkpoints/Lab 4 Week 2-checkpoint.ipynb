# %%
import pandas as pd
import numpy as np
import warnings
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
warnings.filterwarnings('ignore') # no more 'useless' red warnings

# %%
df = pd.read_csv('../files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
data = df.copy()
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
standard_columns = [data.columns[i].lower() for i in range(len(data.columns))]
standard_columns = [col_name.lower().replace(' ', '_') for col_name in data.columns]
data.columns = standard_columns

# %%
data.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
#X-y split
X = data.drop(['total_claim_amount'], axis=1)
y = data['total_claim_amount']

# %%
#Normalizing numerical variables

def boxcox_transform(data):
    numeric_cols = data.select_dtypes(np.number).columns
    _ci = {column: None for column in numeric_cols}
    for column in numeric_cols:
        # since i know any columns should take negative numbers, to avoid -inf in df
        data[column] = np.where(data[column]<=0, np.NAN, data[column]) 
        data[column] = data[column].fillna(data[column].mean())
        transformed_data, ci = stats.boxcox(data[column])
        data[column] = transformed_data
        _ci[column] = [ci] 
    return data, _ci

# %%
data, _ci = boxcox_transform(data)
data
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington                      NaN       No     Basic
# 1     QZ44356     Arizona                      NaN       No  Extended
# 2     AI49188      Nevada                      NaN       No   Premium
# 3     WW63253  California                      NaN       No     Basic
# 4     HB64268  Washington                      NaN       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California                      NaN       No     Basic
# 9130  PK87824  California                      NaN      Yes  Extended
# 9131  TD14365  California                      NaN       No  Extended
# 9132  UP19263  California                      NaN       No  Extended
# 9133  Y167826  California                      NaN       No  Extended
#
#      education effective_to_date employmentstatus gender       income  ...  \
# 0     Bachelor           2/24/11         Employed      F  1240.517275  ...
# 1     Bachelor           1/31/11       Unemployed      F  1160.795864  ...
# 2     Bachelor           2/19/11         Employed      F  1136.972639  ...
# 3     Bachelor           1/20/11       Unemployed      M  1160.795864  ...
# 4     Bachelor            2/3/11         Employed      M  1065.510159  ...
# ...        ...               ...              ...    ...          ...  ...
# 9129  Bachelor           2/10/11         Employed      M  1440.464950  ...
# 9130   College           2/12/11         Employed      F   692.060984  ...
# 9131  Bachelor            2/6/11       Unemployed      M  1160.795864  ...
# 9132   College            2/3/11         Employed      M   698.634769  ...
# 9133   College           2/14/11       Unemployed      M  1160.795864  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                        13.266781                       NaN
# 1                        11.734653                       NaN
# 2                        10.687428                       NaN
# 3                        17.165467                       NaN
# 4                        12.244391                       NaN
# ...                            ...                       ...
# 9129                     22.116484                       NaN
# 9130                      7.870945                       NaN
# 9131                     10.419353                       NaN
# 9132                     13.041299                       NaN
# 9133                     22.311381                       NaN
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                    NaN  Corporate Auto  Corporate L3            Offer1
# 1                    NaN   Personal Auto   Personal L3            Offer3
# 2                    NaN   Personal Auto   Personal L3            Offer1
# 3                    NaN  Corporate Auto  Corporate L2            Offer1
# 4                    NaN   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                 NaN   Personal Auto   Personal L1            Offer2
# 9130                 NaN  Corporate Auto  Corporate L3            Offer1
# 9131                 NaN  Corporate Auto  Corporate L2            Offer1
# 9132                 NaN   Personal Auto   Personal L2            Offer3
# 9133                 NaN  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent          24.474279   Two-Door Car      Medsize
# 1             Agent          42.816969  Four-Door Car      Medsize
# 2             Agent          30.078798   Two-Door Car      Medsize
# 3       Call Center          29.041858            SUV      Medsize
# 4             Agent          13.489783  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web          16.816465  Four-Door Car      Medsize
# 9130         Branch          24.279531  Four-Door Car      Medsize
# 9131         Branch          35.739662  Four-Door Car      Medsize
# 9132         Branch          33.355499  Four-Door Car        Large
# 9133    Call Center          23.942547   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]
